# %%
import pandas as pd

phase = 'P1' # edit which Phase you are analysing - this is used in graph and file generation

df = pd.read_csv('{}_index.csv'.format(phase))
df # check what column headings in file

df[df['Patient'] == 'R0651']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/duncanwilson/Dropbox/code/CASA/hercules/data_import/patient_viewer.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/duncanwilson/Dropbox/code/CASA/hercules/data_import/patient_viewer.ipynb#ch0000000?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/duncanwilson/Dropbox/code/CASA/hercules/data_import/patient_viewer.ipynb#ch0000000?line=2'>3</a> phase = 'P1' # edit which Phase you are analysing - this is used in graph and file generation
#       <a href='vscode-notebook-cell:/Users/duncanwilson/Dropbox/code/CASA/hercules/data_import/patient_viewer.ipynb#ch0000000?line=4'>5</a> df = pd.read_csv('{}_index.csv'.format(phase))
#
# ModuleNotFoundError: No module named 'pandas'
